# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# #### Predicting top items to the user

# %%
DATASET_FILE = 'ratings_Beauty.csv'
amazon_ratings = pd.read_csv(DATASET_FILE)
amazon_ratings = amazon_ratings.dropna()
amazon_ratings.head()
# Out:
#            UserId   ProductId  Rating   Timestamp
# 0  A39HTATAQ9V7YF  0205616461     5.0  1369699200
# 1  A3JM6GV9MNOF9X  0558925278     3.0  1355443200
# 2  A1Z513UWSAAO0F  0558925278     5.0  1404691200
# 3  A1WMRR494NWEWV  0733001998     4.0  1382572800
# 4  A3IAAVS479H7M7  0737104473     1.0  1274227200

# %%
amazon_ratings.shape
# Out:
# (2023070, 4)

# %%
popular_products = pd.DataFrame(amazon_ratings.groupby('ProductId')['Rating'].count())
most_popular = popular_products.sort_values('Rating', ascending=False)
most_popular.head(10)
# Out:
#             Rating
# ProductId
# B001MA0QY2    7533
# B0009V1YR8    2869
# B0043OYFKU    2477
# B0000YUXI0    2143
# B003V265QW    2088
# B000ZMBSPE    2041
# B003BQ6QXK    1918
# B004OHQR1Q    1885
# B00121UVU0    1838
# B000FS05VG    1589

# %%
most_popular.head(30).plot(kind='bar')

# %% [markdown]
# #### Predicting items based on user's previous purchases using collaborative filtering

# %%
amazon_ratings1 = amazon_ratings.head(10000)

# %%
ratings_utility_matrix = amazon_ratings1.pivot_table(values='Rating', index='UserId', columns='ProductId', fill_value=0)
ratings_utility_matrix.head()
# Out:
# ProductId              0205616461  0558925278  0733001998  0737104473  \
# UserId
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A03056581JJIOL5FSKJY7           0           0           0           0
# A03099101ZRK4K607JVHH           0           0           0           0
# A0505229A7NSH3FRXRR4            0           0           0           0
#
# ProductId              0762451459  1304139212  1304139220  130414089X  \
# UserId
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A03056581JJIOL5FSKJY7           0           0           0           0
# A03099101ZRK4K607JVHH           0           0           0           0
# A0505229A7NSH3FRXRR4            0           0           0           0
#
# ProductId              130414643X  1304146537  ...  B000052YPE  B000052YPF  \
# ...

# %%
X = ratings_utility_matrix.T
X.head()
# Out:
# UserId      A00205921JHJK5X9LNP42  A024581134CV80ZBLIZTZ  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# 0737104473                      0                      0
# 0762451459                      0                      0
#
# UserId      A03056581JJIOL5FSKJY7  A03099101ZRK4K607JVHH  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# 0737104473                      0                      0
# 0762451459                      0                      0
#
# UserId      A0505229A7NSH3FRXRR4  A05492663T95KW63BR75K  \
# ProductId
# 0205616461                     0                      0
# 0558925278                     0                      0
# 0733001998                     0                      0
# ...

# %%
X1 = X

# %%
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (886, 10)

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (886, 886)

# %%
X.index[99]
# Out:
# '6117036094'

# %%
i = "6117036094"
product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 99

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (886,)

# %%
Recommendation = list(X.index[correlation_product_ID > 0.9])
Recommendation.remove(i)

Recommendation[0:9]
# Out:
# ['6162751473',
#  '9510213861',
#  '9602617918',
#  '978807250X',
#  '9788072828',
#  '9788078907',
#  '9790793294',
#  '9790798393',
#  '9839215027']
